# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# * Jaccard Distance
# * Binary Cross Entropy
# * Dice Loss
# * Focal Loss

# %%
import tensorflow as tf
from keras import backend as K

def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis=-1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

def binary_cross_entropy(y_true, y_pred):
    return K.mean(K.binary_crossentropy(y_true, y_pred), axis=-1)

def dice_loss(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=-1)
    union = K.sum(y_true, axis=-1) + K.sum(y_pred, axis=-1)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

def focal_loss(y_true, y_pred, gamma=2., alpha=0.25):
    y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
    pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
    pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
    return -K.mean(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) - K.mean((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))

# %% [markdown]
# ## Defining Evaluation Metrics

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model
#
# #

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %% [markdown]
# **Model 1 - UNET_Simple**

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_Simple(epochs_num, savename, loss_function):
    dropout_val = 0.50
    if K.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    # Here we're removing some layers from the original architecture
    #conv_7 = double_conv_layer(pool_7, 32*filters)

    #up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    #up_conv_14 = double_conv_layer(up_14, 16*filters)

    #up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    #up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(conv_28), conv_56], axis=axis)  # Changed from conv_28 to conv_56
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224, 224))(conv_final)
    model = Model(inputs, pred, name="UNET_Simple")

    # Compile the model with the specified loss function
    model.compile(optimizer=Adam(lr=0.003), loss=loss_function,
                  metrics=[iou, dice_coe, precision, recall, accuracy])

    model.summary()

    # Train the model with specified number of epochs
    hist = model.fit(x_train, y_train, epochs=epochs_num, batch_size=18,
                     validation_data=(x_val, y_val), verbose=1)

    # Save the model
    model.save(savename)

    # Return the trained model and history
    return model, hist


# Define list of loss functions
loss_functions = [jaccard_distance, binary_cross_entropy, dice_loss, focal_loss]
loss_names = ['Jaccard Distance', 'Binary Crossentropy', 'Dice Loss', 'Focal Loss']

# Train models with different loss functions
for loss_func, loss_name in zip(loss_functions, loss_names):
    print(f"Training with {loss_name} Loss:")
    model, hist = UNET_Simple(100, f"model_{loss_name}.h5", loss_func)  # Change epochs_num to 10
    
    # Evaluate the model on validation data
    val_metrics = model.evaluate(x_val, y_val, batch_size=18, verbose=0)
    
    # Print the validation metrics
    print(f"Validation Metrics for {loss_name} Loss:")
    print(f"IOU: {val_metrics[1]*100:.2f}%")
    print(f"Dice Coef: {val_metrics[2]*100:.2f}%")
    print(f"Precision: {val_metrics[3]*100:.2f}%")
    print(f"Recall: {val_metrics[4]*100:.2f}%")
    print(f"Accuracy: {val_metrics[5]*100:.2f}%")
    print(f"Loss: {val_metrics[0]*100:.2f}%")
    print("\n")
# Out:
# Training with Jaccard Distance Loss:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 224, 224, 32) 896         input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 224, 224, 32) 128         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 224, 224, 32) 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 224, 224, 32) 9248        activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 224, 224, 32) 128         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 224, 224, 32) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_66 (SpatialDr (None, 224, 224, 32) 0           activation_139[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 112, 112, 64) 18496       max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 112, 112, 64) 256         conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 112, 112, 64) 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 112, 112, 64) 36928       activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 112, 112, 64) 256         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 112, 112, 64) 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_67 (SpatialDr (None, 112, 112, 64) 0           activation_141[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 56, 56, 128)  73856       max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 56, 56, 128)  512         conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 56, 56, 128)  0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 56, 56, 128)  147584      activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 56, 56, 128)  512         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 56, 56, 128)  0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_68 (SpatialDr (None, 56, 56, 128)  0           activation_143[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 28, 28, 256)  295168      max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 28, 28, 256)  1024        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 28, 28, 256)  0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 28, 28, 256)  590080      activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 28, 28, 256)  1024        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 28, 28, 256)  0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_69 (SpatialDr (None, 28, 28, 256)  0           activation_145[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_28 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_69[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_28[0][0]
#                                                                  spatial_dropout2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 56, 56, 128)  442496      concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 56, 56, 128)  512         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 56, 56, 128)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 56, 56, 128)  147584      activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 56, 56, 128)  512         conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 56, 56, 128)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_71 (SpatialDr (None, 56, 56, 128)  0           activation_149[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_29 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_71[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_29[0][0]
#                                                                  spatial_dropout2d_67[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 112, 112, 64) 110656      concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 112, 112, 64) 256         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 112, 112, 64) 0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 112, 112, 64) 36928       activation_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 112, 112, 64) 256         conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 112, 112, 64) 0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_72 (SpatialDr (None, 112, 112, 64) 0           activation_151[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_30 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_72[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_30[0][0]
#                                                                  spatial_dropout2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 224, 224, 32) 27680       concatenate_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 224, 224, 32) 128         conv2d_152[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 224, 224, 32) 0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 224, 224, 32) 9248        activation_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 224, 224, 32) 128         conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 224, 224, 32) 0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_73 (SpatialDr (None, 224, 224, 32) 0           activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 224, 224, 1)  33          spatial_dropout2d_73[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 224, 224, 1)  0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 224, 224)     0           activation_154[0][0]
# ==================================================================================================
# Total params: 1,952,513
# Trainable params: 1,949,697
# Non-trainable params: 2,816
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 18s 50ms/step - loss: 0.1763 - iou: 0.8237 - dice_coe: 0.6080 - precision: 0.7012 - recall: 0.6864 - accuracy: 0.7931 - val_loss: 0.3981 - val_iou: 0.6019 - val_dice_coe: 0.5325 - val_precision: 0.3689 - val_recall: 0.9964 - val_accuracy: 0.4660
# Epoch 2/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0
100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0220 - iou: 0.8990 - dice_coe: 0.6609 - precision: 0.9563 - recall: 0.7599 - accuracy: 0.9073 - val_loss: 0.0274 - val_iou: 0.8914 - val_dice_coe: 0.6608 - val_precision: 0.8798 - val_recall: 0.8734 - val_accuracy: 0.9232
# Epoch 95/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0220 - iou: 0.8977 - dice_coe: 0.6579 - precision: 0.9624 - recall: 0.7375 - accuracy: 0.9038 - val_loss: 0.0206 - val_iou: 0.9274 - val_dice_coe: 0.7313 - val_precision: 0.8994 - val_recall: 0.8875 - val_accuracy: 0.9345
# Epoch 96/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0241 - iou: 0.8941 - dice_coe: 0.6504 - precision: 0.9484 - recall: 0.7515 - accuracy: 0.9007 - val_loss: 0.0255 - val_iou: 0.8748 - val_dice_coe: 0.6206 - val_precision: 0.9420 - val_recall: 0.7611 - val_accuracy: 0.9091
# Epoch 97/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0230 - iou: 0.8912 - dice_coe: 0.6415 - precision: 0.9648 - recall: 0.7196 - accuracy: 0.8957 - val_loss: 0.0278 - val_iou: 0.8935 - val_dice_coe: 0.6603 - val_precision: 0.8613 - val_recall: 0.8935 - val_accuracy: 0.9203
# Epoch 98/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0220 - iou: 0.8995 - dice_coe: 0.6590 - precision: 0.9599 - recall: 0.7558 - accuracy: 0.9086 - val_loss: 0.0233 - val_iou: 0.9064 - val_dice_coe: 0.6798 - val_precision: 0.8717 - val_recall: 0.8963 - val_accuracy: 0.9268
# Epoch 99/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0207 - iou: 0.9024 - dice_coe: 0.6672 - precision: 0.9568 - recall: 0.7631 - accuracy: 0.9095 - val_loss: 0.0258 - val_iou: 0.8954 - val_dice_coe: 0.6650 - val_precision: 0.8874 - val_recall: 0.8848 - val_accuracy: 0.9290
# Epoch 100/100
# 360/360 [==============================] - 8s 22ms/step - loss: 0.0216 - iou: 0.9046 - dice_coe: 0.6772 - precision: 0.9509 - recall: 0.7709 - accuracy: 0.9110 - val_loss: 0.0239 - val_iou: 0.8951 - val_dice_coe: 0.6652 - val_precision: 0.9215 - val_recall: 0.8181 - val_accuracy: 0.9194
# Validation Metrics for Focal Loss Loss:
# IOU: 89.51%
# Dice Coef: 66.52%
# Precision: 92.15%
# Recall: 81.81%
# Accuracy: 91.94%
# Loss: 2.39%

# %% [markdown]
# **Model 2 UNET_224**

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename, loss_function):
    dropout_val = 0.50
    if K.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224, 224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")

    # Compile the model with the specified loss function
    model.compile(optimizer=Adam(lr=0.003), loss=loss_function,
                  metrics=[iou, dice_coe, precision, recall, accuracy])

    model.summary()

    # Train the model with specified number of epochs
    hist = model.fit(x_train, y_train, epochs=epochs_num, batch_size=18,
                     validation_data=(x_val, y_val), verbose=1)

    # Save the model
    model.save(savename)

    # Return the trained model and history
    return model, hist

# Define list of loss functions
loss_functions = [jaccard_distance, binary_cross_entropy, dice_loss, focal_loss]
loss_names = ['Jaccard Distance', 'Binary Crossentropy', 'Dice Loss', 'Focal Loss']

# Train models with different loss functions
for loss_func, loss_name in zip(loss_functions, loss_names):
    print(f"Training with {loss_name} Loss:")
    model, hist = UNET_224(100, f"model_{loss_name}.h5", loss_func)  # Change epochs_num to 10
    
    # Evaluate the model on validation data
    val_metrics = model.evaluate(x_val, y_val, batch_size=18, verbose=0)
    
    # Print the validation metrics
    print(f"Validation Metrics for {loss_name} Loss:")
    print(f"IOU: {val_metrics[1]*100:.2f}%")
    print(f"Dice Coef: {val_metrics[2]*100:.2f}%")
    print(f"Precision: {val_metrics[3]*100:.2f}%")
    print(f"Recall: {val_metrics[4]*100:.2f}%")
    print(f"Accuracy: {val_metrics[5]*100:.2f}%")
    print(f"Loss: {val_metrics[0]*100:.2f}%")
    print("\n")
# Out:
# Training with Jaccard Distance Loss:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 224, 224, 32) 896         input_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 224, 224, 32) 128         conv2d_206[0][0]
# __________________________________________________________________________________________________
# activation_206 (Activation)     (None, 224, 224, 32) 0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 224, 224, 32) 9248        activation_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 224, 224, 32) 128         conv2d_207[0][0]
# __________________________________________________________________________________________________
# activation_207 (Activation)     (None, 224, 224, 32) 0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_98 (SpatialDr (None, 224, 224, 32) 0           activation_207[0][0]
# __________________________________________________________________________________________________
# max_pooling2d
0][0]
# __________________________________________________________________________________________________
# up_sampling2d_43 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_106[0][0]
# __________________________________________________________________________________________________
# concatenate_43 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_43[0][0]
#                                                                  spatial_dropout2d_99[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 112, 112, 64) 110656      concatenate_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 112, 112, 64) 256         conv2d_224[0][0]
# __________________________________________________________________________________________________
# activation_224 (Activation)     (None, 112, 112, 64) 0           batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 112, 112, 64) 36928       activation_224[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 112, 112, 64) 256         conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_225 (Activation)     (None, 112, 112, 64) 0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_107 (SpatialD (None, 112, 112, 64) 0           activation_225[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_44 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_107[0][0]
# __________________________________________________________________________________________________
# concatenate_44 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_44[0][0]
#                                                                  spatial_dropout2d_98[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 224, 224, 32) 27680       concatenate_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 224, 224, 32) 128         conv2d_226[0][0]
# __________________________________________________________________________________________________
# activation_226 (Activation)     (None, 224, 224, 32) 0           batch_normalization_215[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 224, 224, 32) 9248        activation_226[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 224, 224, 32) 128         conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_227 (Activation)     (None, 224, 224, 32) 0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_108 (SpatialD (None, 224, 224, 32) 0           activation_227[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 224, 224, 1)  33          spatial_dropout2d_108[0][0]
# __________________________________________________________________________________________________
# activation_228 (Activation)     (None, 224, 224, 1)  0           conv2d_228[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 224, 224)     0           activation_228[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 28s 79ms/step - loss: 0.1714 - iou: 0.8286 - dice_coe: 0.6060 - precision: 0.7032 - recall: 0.6750 - accuracy: 0.7971 - val_loss: 0.3317 - val_iou: 0.6683 - val_dice_coe: 0.0465 - val_precision: 0.2589 - val_recall: 0.0234 - val_accuracy: 0.6698
# Epoch 2/100
# 360/360 [==============================] - 10s 29ms/step - loss: 0.1035 - iou: 0.8965 - dice_coe: 0.7344 - precision: 0.8534 - recall: 0.7854 - accuracy: 0.8851 - val_loss: 0.4672 - val_iou: 0.5328 - val_dice_coe: 0.4799 - val_precision: 0.3175 - val_recall: 0.9974 - val_accuracy: 0.3286
# Epoch 3/100
# 360/360 [==============================] - 11s 29ms/step - loss: 0.0982 - iou: 0.9018 - dice_coe: 0.7496 - precision: 0.8631 - recall: 0.7949 - accuracy: 0.8899 - val_loss: 0.3583 - val_iou: 0.6417 - val_dice_coe: 0.5560 - val_precision: 0.3886 - val_recall: 0.9871 - val_accuracy: 0.5131
# Epoch 4/100
# 360/360 [==============================] - 11s 29ms/step - loss: 0.0949 - iou: 0.9051 - dice_coe: 0.7663 - precision: 0.8750 - recall: 0.7944 - accuracy: 0.8928 - val_loss: 0.2858 - val_iou: 0.7142 - val_dice_coe: 0.5779 - val_precision: 0.4564 - val_recall: 0.7941 - val_accuracy: 0.6358
# Epoch 5/100
# 360/360 [==============================] - 11s 29ms/step - loss: 0.0936 - iou: 0.9064 - dice_coe: 0.7662 - precision: 0.8774 - recall: 0.7836 - accuracy: 0.8913 - val_loss: 0.1291 - val_iou: 0.8709 - val_dice_coe: 0.7933 - val_precision: 0.7469 - val_recall: 0.8809 - val_accuracy: 0.8700
# Epoch 6/100
# 360/360 [==============================] - 10s 29ms/step - loss: 0.0873 - iou: 0.9127 - dice_coe: 0.7863 - precision: 0.8605 - recall: 0.8311 - accuracy: 0.9001 - val_loss: 0.1019 - val_iou: 0.8981 - val_dice_coe: 0.8137 - val_precision: 0.8754 - val_recall: 0.7766 - val_accuracy: 0.8945
# Epoch 7/100
# 360/360 [==============================] - 10s 29ms/step - loss: 0.